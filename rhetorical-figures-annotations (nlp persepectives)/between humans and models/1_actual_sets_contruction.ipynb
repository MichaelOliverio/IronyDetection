# %%
import pandas as pd
import numpy as np
from statsmodels.stats.inter_rater import fleiss_kappa
import simpledorff  # per Krippendorff come prima

# %%
file_name = "../annotated_multipico_new.xlsx"
sheet_names = ['Alessandro', 'Cristina', 'Eliana', 'Michele', 'Michael', 'Elisa']
df = pd.read_excel(file_name, sheet_name=sheet_names)
df['Alessandro'].head()
# Out:
#    level   source                                              reply  \
# 0      2  twitter         @USER  @USER Anche per rompere il ghiaccio
# 1      2  twitter                     @USER Nonnino! Già sveglio? ??
# 2      1  twitter             @USER il terrone di essere rimpiazzata
# 3      1  twitter                  @USER Tanto per non essere banali
# 4      1   reddit  Se le toghe rosse avessere mandato un avviso d...
#
#                                                 post language  \
# 0  @USER Gianca già che ci sei regalale un paio d...       it
# 1                        @USER Non troppo buongiorno       it
# 2                   il terrore di essere rimpiazzata       it
# 3  Elly #Schlein: "Il lavoro deve tornare a esser...       it
# 4  Se solo la società perseguisse l'obiettivo di ...       it
#
#   language_variety              reply_id               post_id majority_vote  \
# 0               it  15902900000000000000   7961696982295378944             1
# 1               it   4652170000000000000   4824587311292975104             1
# 2               it  18161900000000000000   7155693771356047360             1
# 3               it   5855670000000000000   5929177359346716672             1
# 4               it  10284800000000000000  12099038560420169728             1
#
#    Unnamed: 9               rhetorical figure  comment
# 0         NaN        CONTEXT SHIFT, HYPERBOLE      NaN
# 1         NaN  RHETORICAL QUESTION, HYPERBOLE      NaN
# 2         NaN            CONTEXT SHIFT, OTHER      NaN
# 3         NaN                 FALSE ASSERTION      NaN
# 4         NaN               OXYMORON, ANALOGY      NaN

# %%
file_name = "../annotated_multipico_new.xlsx"
sheet_names = ['Alessandro', 'Cristina', 'Eliana', 'Michele', 'Michael', 'Elisa']

# Carico solo il foglio di Cristina
df_cristina = pd.read_excel(file_name, sheet_name='Cristina')
colonna_rf = df_cristina['rhetorical figure']

# Trovo l'indice dell'ultima riga non vuota nella colonna 'rhetorical figure' di Cristina
ultima_riga_non_vuota = colonna_rf.last_valid_index()
print("L'ultima riga annotata da Cristina (per la colonna rhetorical figure) è:", ultima_riga_non_vuota)

# Ora carico tutti gli sheet
df_dict = pd.read_excel(file_name, sheet_name=sheet_names)

# Taglio ogni DataFrame fino all'ultima riga non vuota annotata da Cristina
# ATTENZIONE: last_valid_index() è l'indice dell'ultima riga valida, potrebbe essere un numero qualsiasi,
# bisogna verificare se è un indice numerico o un indice di riga (se è un RangeIndex tipicamente lo è)
# Assumiamo che sia un indice numerico, quindi per prendere le prime righe useremo .iloc[:ultima_riga_non_vuota + 1]

df_dict_truncated = {}
for sheet, df in df_dict.items():
    df_dict_truncated[sheet] = df.iloc[:ultima_riga_non_vuota + 1]

# Ora df_dict_truncated contiene tutti i DataFrame tagliati al numero di righe di Cristina
df = df_dict_truncated
# Out:
# L'ultima riga annotata da Cristina (per la colonna rhetorical figure) è: 121

# %%
# DROP colonne indesiderate subito dopo il caricamento
cols_to_drop = ['level', 'source', 'language', 'language_variety', 'majority_vote', 'Unnamed: 9', 'comment']
for name in df:
    df[name] = df[name].drop(columns=[col for col in cols_to_drop if col in df[name].columns])
    # Aggiungi la colonna 'indice' con il valore dell'indice di ogni riga
    df[name]['index'] = df[name].index
df['Alessandro'].head()
# Out:
#                                                reply  \
# 0         @USER  @USER Anche per rompere il ghiaccio
# 1                     @USER Nonnino! Già sveglio? ??
# 2             @USER il terrone di essere rimpiazzata
# 3                  @USER Tanto per non essere banali
# 4  Se le toghe rosse avessere mandato un avviso d...
#
#                                                 post              reply_id  \
# 0  @USER Gianca già che ci sei regalale un paio d...  15902900000000000000
# 1                        @USER Non troppo buongiorno   4652170000000000000
# 2                   il terrore di essere rimpiazzata  18161900000000000000
# 3  Elly #Schlein: "Il lavoro deve tornare a esser...   5855670000000000000
# 4  Se solo la società perseguisse l'obiettivo di ...  10284800000000000000
#
#                 post_id               rhetorical figure  index
# 0   7961696982295378944        CONTEXT SHIFT, HYPERBOLE      0
# 1   4824587311292975104  RHETORICAL QUESTION, HYPERBOLE      1
# 2   7155693771356047360            CONTEXT SHIFT, OTHER      2
# 3   5929177359346716672                 FALSE ASSERTION      3
# 4  12099038560420169728               OXYMORON, ANALOGY      4

# %%
# Per ogni foglio, tieni solo righe con 'rhetorical figure' non-NaN
'''cleaned = {
    name: sheet[sheet['rhetorical figure'].notna()][['post_id', 'reply_id']]
    for name, sheet in df.items()
}

sets_of_pairs = [set(zip(sheet['post_id'], sheet['reply_id'])) for sheet in cleaned.values()]
common_pairs = set.intersection(*sets_of_pairs)
print(f"Coppie (post_id, reply_id) comuni con 'rhetorical figure' non-NaN in tutti i fogli: {len(common_pairs)}")

final_cleaned = {}
for name, sheet in df.items():
    mask = sheet.apply(lambda row: (row['post_id'], row['reply_id']) in common_pairs, axis=1)
    mask &= sheet['rhetorical figure'].notna()
    final_cleaned[name] = sheet[mask].copy()

for sheet_name in sheet_names:
    print(f"Numero di post in {sheet_name}: {len(final_cleaned[sheet_name])}")

final_cleaned['Alessandro'].head()'''
final_cleaned = df
final_cleaned['Michele'].iloc[27:32]
# Out:
#                                                 reply  \
# 27                            Se po buccà chi drento?
# 28                        @USER  @USER Tarlo mentale.
# 29  @USER  @USER La giustizia e' aliena su questo ...
# 30  Perché avere delle bottiglie di vino a casa qu...
# 31                                      @USER I don’t
#
#                                                  post              reply_id  \
# 27               Siamo sicuri non sia matteo montesi?  10540900000000000000
# 28  @USER  @USER Per esiliare dal suo amico sceicc...   6975850000000000000
# 29                   @USER  @USER Sì ma non è Giusto.  15962200000000000000
# 30  Io non ho mai capito perché si dovrebbero salv...   5036060000000000000
# 31     @USER Non essere così cattivo con lei...❤️❤️❤️  16985200000000000000
#
#                  post_id    rhetorical figure  index
# 27   1004779540710112000                OTHER     27
# 28  10742053278056030208                  NaN     28
# 29  14374185223286280192                  NaN     29
# 30  16167343742615099392  RHETORICAL QUESTION     30
# 31   4320113204215145984                  NaN     31

# %%
len(final_cleaned['Michele'])
# Out:
# 122

# %%
# Estrai tutte le figure retoriche da tutti i fogli, normalizzate
all_figures_set = set()

def normalize_figures(cell):
    # Gestione NaN
    if pd.isna(cell):
        return []
    figures = [f.strip().upper() for f in str(cell).split(',')]
    # Sostituzione specifica
    figures = ["OXYMORON" if f == "OXYMORON/PARADOX" else f for f in figures]
    figures = ["EUPHEMISM" if f == "EUPHEMINSM" else f for f in figures]
    return figures

# Raccogli tutte le figure da tutti i fogli
for sheet in final_cleaned.values():
    for entry in sheet['rhetorical figure'].dropna():
        all_figures_set.update(normalize_figures(entry))

# Ordina per consistenza
all_figures = sorted(all_figures_set)

# Aggiungi una colonna per ciascuna figura: 1 se presente, 0 altrimenti
for name, sheet in final_cleaned.items():
    for fig in all_figures:
        sheet[fig] = sheet['rhetorical figure'].apply(
            lambda x: 1 if fig in normalize_figures(x) else 0
        )
    final_cleaned[name] = sheet  # Aggiorna

final_cleaned['Alessandro'].head()
# Out:
#                                                reply  \
# 0         @USER  @USER Anche per rompere il ghiaccio
# 1                     @USER Nonnino! Già sveglio? ??
# 2             @USER il terrone di essere rimpiazzata
# 3                  @USER Tanto per non essere banali
# 4  Se le toghe rosse avessere mandato un avviso d...
#
#                                                 post              reply_id  \
# 0  @USER Gianca già che ci sei regalale un paio d...  15902900000000000000
# 1                        @USER Non troppo buongiorno   4652170000000000000
# 2                   il terrore di essere rimpiazzata  18161900000000000000
# 3  Elly #Schlein: "Il lavoro deve tornare a esser...   5855670000000000000
# 4  Se solo la società perseguisse l'obiettivo di ...  10284800000000000000
#
#                 post_id               rhetorical figure  index  ANALOGY  \
# 0   7961696982295378944        CONTEXT SHIFT, HYPERBOLE      0        0
# 1   4824587311292975104  RHETORICAL QUESTION, HYPERBOLE      1        0
# 2   7155693771356047360            CONTEXT SHIFT, OTHER      2        0
# 3   5929177359346716672                 FALSE ASSERTION      3        0
# 4  12099038560420169728               OXYMORON, ANALOGY      4        1
#
#    CONTEXT SHIFT  EUPHEMISM  FALSE ASSERTION  HYPERBOLE  OTHER  OXYMORON  \
# 0              1          0                0          1      0         0
# 1              0          0                0          1      0         0
# 2              1          0                0          0      1         0
# 3              0          0                1          0      0         0
# 4              0          0                0          0      0         1
#
#    RHETORICAL QUESTION
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ## Complessivo: Estrazione etichetta più frequente per ogni record

# %%
import pandas as pd

# Numero annotatori e lista annotatori
num_annotators = len(sheet_names)
print(f"Numero di annotatori: {num_annotators}")

# Prepara i dataframe indicizzati
dfs_figs = []
for name in sheet_names:
    df_tmp = final_cleaned[name][['post_id', 'reply_id', 'index'] + all_figures].copy()
    dfs_figs.append(df_tmp.set_index(['post_id', 'reply_id', 'index']))

# Trova record comuni
common_index = dfs_figs[0].index
for df_tmp in dfs_figs[1:]:
    common_index = common_index.intersection(df_tmp.index)

results = []

for idx in common_index:
    # Matrice annotatori x figure per il record
    matrix = pd.DataFrame([df.loc[idx].values for df in dfs_figs], columns=all_figures)

    # Conta annotatori per figura
    votes_per_figure = matrix.sum(axis=0)
    print(f"Record {idx}: voti per figura: {votes_per_figure.to_dict()}")
    
    max_votes = votes_per_figure.max()  # Se c'è un pareggio prende casualmente la prima in ordine alfabetico
    # Trova figure con max voti
    top_figures = votes_per_figure[votes_per_figure == max_votes].index.tolist()
    
    # Scegli la prima in ordine alfabetico
    top_label = sorted(top_figures)[0] if top_figures else None
    print(f"Record {idx}: figura con max voti: {top_label} ({max_votes} voti)")
    

    results.append({
        'index': idx[2],
        'post_id': idx[0],
        'reply_id': idx[1],
        'most_frequent_label': top_label,
        'votes': max_votes
    })
    
    print('\n')

df_most_frequent = pd.DataFrame(results)
print(len(df_most_frequent))
# Out:
# Numero di annotatori: 6
# Record (7961696982295378944, 15902900000000000000, 0): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 5, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 3, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (7961696982295378944, 15902900000000000000, 0): figura con max voti: CONTEXT SHIFT (5 voti)
#
#
# Record (4824587311292975104, 4652170000000000000, 1): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 0, 'OXYMORON': 2, 'RHETORICAL QUESTION': 5}
# Record (4824587311292975104, 4652170000000000000, 1): figura con max voti: RHETORICAL QUESTION (5 voti)
#
#
# Record (7155693771356047360, 18161900000000000000, 2): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 5, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (7155693771356047360, 18161900000000000000, 2): figura con max voti: OTHER (5 voti)
#
#
# Record (5929177359346716672, 5855670000000000000, 3): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 3, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (5929177359346716672, 5855670000000000000, 3): figura con max voti: EUPHEMISM (3 voti)
#
#
# Record (12099038560420169728, 10284800000000000000, 4): voti per figura: {'ANALOGY': 4, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 2, 'RHETORICAL QUESTION': 0}
# Record (12099038560420169728, 10284800000000000000, 4): figura con max voti: ANALOGY (4 voti)
#
#
# Record (6878336134883742720, 15991800000000000000, 5): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (6878336134883742720, 15991800000000000000, 5): figura con max voti: OTHER (3 voti)
#
#
# Record (18184193230015000576, 3263700000000000000, 6): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 2, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (18184193230015000576, 3263700000000000000, 6): figura con max voti: OTHER (3 voti)
#
#
# Record (4625931298966675456, 3210680000000000000, 7): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 6, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (4625931298966675456, 3210680000000000000, 7): figura con max voti: HYPERBOLE (6 voti)
#
#
# Record (457436274759233728, 11247500000000000000, 8): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (457436274759233728, 11247500000000000000, 8): figura con max voti: CONTEXT SHIFT (2 voti)
#
#
# Record (12841824500967149568, 13599000000000000000, 9): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (12841824500967149568, 13599000000000000000, 9): figura con max voti: OTHER (3 voti)
#
#
# Record (8374295896122236928, 9960700000000000000, 10): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 3, 'HYPERBOLE': 1, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (8374295896122236928, 9960700000000000000, 10): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (1439242534760017920, 10568700000000000000, 11): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 1}
# Record (1439242534760017920, 10568700000000000000, 11): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (8727623984665907200, 457492000000000000, 12): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 1, 'OTHER': 3, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (8727623984665907200, 457492000000000000, 12): figura con max voti: OTHER (3 voti)
#
#
# Record (7033897647878070272, 4174370000000000000, 13): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 4, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (7033897647878070272, 4174370000000000000, 13): figura con max voti: CONTEXT SHIFT (4 voti)
#
#
# Record (14927487631298500608, 3984510000000000000, 14): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (14927487631298500608, 3984510000000000000, 14): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (13999466197412390912, 8582060000000000000, 15): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 1, 'RHETORICAL QUESTION': 3}
# Record (13999466197412390912, 8582060000000000000, 15): figura con max voti: RHETORICAL QUESTION (3 voti)
#
#
# Record (3045493691802176000, 5881810000000000000, 16): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 2, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (3045493691802176000, 5881810000000000000, 16): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (1679217763483685120, 5478910000000000000, 17): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 3, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (1679217763483685120, 5478910000000000000, 17): figura con max voti: HYPERBOLE (3 voti)
#
#
# Record (17571549064257740800, 12383100000000000000, 18): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 4, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (17571549064257740800, 12383100000000000000, 18): figura con max voti: OTHER (4 voti)
#
#
# Record (1894119167367809024, 9033280000000000000, 19): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 0, 'OTHER': 4, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (1894119167367809024, 9033280000000000000, 19): figura con max voti: OTHER (4 voti)
#
#
# Record (7462581045673427968, 14235400000000000000, 20): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 5}
# Record (7462581045673427968, 14235400000000000000, 20): figura con max voti: RHETORICAL QUESTION (5 voti)
#
#
# Record (13615235974994190336, 17921100000000000000, 21): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 3, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 4}
# Record (13615235974994190336, 17921100000000000000, 21): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (10765217889857900544, 12979700000000000000, 22): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (10765217889857900544, 12979700000000000000, 22): figura con max voti: OTHER (3 voti)
#
#
# Record (15318882553031809024, 1457720000000000000, 23): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 4, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (15318882553031809024, 1457720000000000000, 23): figura con max voti: CONTEXT SHIFT (4 voti)
#
#
# Record (17212309861089630208, 7213440000000000000, 24): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 5, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (17212309861089630208, 7213440000000000000, 24): figura con max voti: FALSE ASSERTION (5 voti)
#
#
# Record (10543569204621709312, 6478110000000000000, 25): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 5}
# Record (10543569204621709312, 6478110000000000000, 25): figura con max voti: RHETORICAL QUESTION (5 voti)
#
#
# Record (5168625731641847808, 6591050000000000000, 26): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 2, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (5168625731641847808, 6591050000000000000, 26): figura con max voti: CONTEXT SHIFT (2 voti)
#
#
# Record (1004779540710112000, 10540900000000000000, 27): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (1004779540710112000, 10540900000000000000, 27): figura con max voti: OTHER (3 voti)
#
#
# Record (10742053278056030208, 6975850000000000000, 28): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (10742053278056030208, 6975850000000000000, 28): figura con max voti: ANALOGY (1 voti)
#
#
# Record (14374185223286280192, 15962200000000000000, 29): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 2, 'FALSE ASSERTION': 1, 'HYPERBOLE': 3, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (14374185223286280192, 15962200000000000000, 29): figura con max voti: HYPERBOLE (3 voti)
#
#
# Record (16167343742615099392, 5036060000000000000, 30): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (16167343742615099392, 5036060000000000000, 30): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (4320113204215145984, 16985200000000000000, 31): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 4, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (4320113204215145984, 16985200000000000000, 31): figura con max voti: OTHER (4 voti)
#
#
# Record (10294703797536010240, 14854400000000000000, 32): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (10294703797536010240, 14854400000000000000, 32): figura con max voti: OTHER (3 voti)
#
#
# Record (1387389979920722944, 7871260000000000000, 33): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 1, 'RHETORICAL QUESTION': 2}
# Record (1387389979920722944, 7871260000000000000, 33): figura con max voti: CONTEXT SHIFT (2 voti)
#
#
# Record (8657171621256952832, 5812260000000000000, 34): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (8657171621256952832, 5812260000000000000, 34): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (955066013186157056, 7841040000000000000, 35): voti per figura: {'ANALOGY': 3, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 4}
# Record (955066013186157056, 7841040000000000000, 35): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (9117711307358630912, 7916660000000000000, 36): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (9117711307358630912, 7916660000000000000, 36): figura con max voti: CONTEXT SHIFT (2 voti)
#
#
# Record (4178595591294574080, 16143900000000000000, 37): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 4, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (4178595591294574080, 16143900000000000000, 37): figura con max voti: FALSE ASSERTION (4 voti)
#
#
# Record (10274209232461860864, 1533160000000000000, 38): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 5, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (10274209232461860864, 1533160000000000000, 38): figura con max voti: CONTEXT SHIFT (5 voti)
#
#
# Record (11611645251669049344, 7556330000000000000, 39): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (11611645251669049344, 7556330000000000000, 39): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (225288318251128288, 4629310000000000000, 40): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 6, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (225288318251128288, 4629310000000000000, 40): figura con max voti: HYPERBOLE (6 voti)
#
#
# Record (7892378751459500032, 16252800000000000000, 41): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 2, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 4}
# Record (7892378751459500032, 16252800000000000000, 41): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (11369149162983489536, 7888320000000000000, 42): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (11369149162983489536, 7888320000000000000, 42): figura con max voti: OTHER (3 voti)
#
#
# Record (11558390939674519552, 12676400000000000000, 43): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 4, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (11558390939674519552, 12676400000000000000, 43): figura con max voti: HYPERBOLE (4 voti)
#
#
# Record (15313632188181430272, 1809560000000000000, 44): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 5}
# Record (15313632188181430272, 1809560000000000000, 44): figura con max voti: RHETORICAL QUESTION (5 voti)
#
#
# Record (18387398790699239424, 14325300000000000000, 45): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 4, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (18387398790699239424, 14325300000000000000, 45): figura con max voti: CONTEXT SHIFT (4 voti)
#
#
# Record (630286693384318080, 11609600000000000000, 46): voti per figura: {'ANALOGY': 4, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 3, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (630286693384318080, 11609600000000000000, 46): figura con max voti: ANALOGY (4 voti)
#
#
# Record (18083945283865270272, 13051300000000000000, 47): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 3, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (18083945283865270272, 13051300000000000000, 47): figura con max voti: EUPHEMISM (3 voti)
#
#
# Record (393080136253742016, 16904200000000000000, 48): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 5, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (393080136253742016, 16904200000000000000, 48): figura con max voti: CONTEXT SHIFT (5 voti)
#
#
# Record (11926712388159440896, 17502200000000000000, 49): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 4, 'OXYMORON': 1, 'RHETORICAL QUESTION': 1}
# Record (11926712388159440896, 17502200000000000000, 49): figura con max voti: OTHER (4 voti)
#
#
# Record (9568837740787623936, 2564980000000000000, 50): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 2, 'OTHER': 2, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (9568837740787623936, 2564980000000000000, 50): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (1096004385442002944, 18443900000000000000, 51): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 4, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (1096004385442002944, 18443900000000000000, 51): figura con max voti: HYPERBOLE (4 voti)
#
#
# Record (13530102438651389952, 4840720000000000000, 52): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (13530102438651389952, 4840720000000000000, 52): figura con max voti: OTHER (3 voti)
#
#
# Record (14048408814207320064, 15664700000000000000, 53): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (14048408814207320064, 15664700000000000000, 53): figura con max voti: RHETORICAL QUESTION (3 voti)
#
#
# Record (11137418050832379904, 3817000000000000000, 54): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 3}
# Record (11137418050832379904, 3817000000000000000, 54): figura con max voti: RHETORICAL QUESTION (3 voti)
#
#
# Record (10281194885854019584, 14278400000000000000, 55): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 5, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (10281194885854019584, 14278400000000000000, 55): figura con max voti: CONTEXT SHIFT (5 voti)
#
#
# Record (3564946252259166208, 11499800000000000000, 56): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 1, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 6}
# Record (3564946252259166208, 11499800000000000000, 56): figura con max voti: RHETORICAL QUESTION (6 voti)
#
#
# Record (6386761469479286784, 6876180000000000000, 57): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (6386761469479286784, 6876180000000000000, 57): figura con max voti: CONTEXT SHIFT (2 voti)
#
#
# Record (7954843239286609920, 8178510000000000000, 58): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 4, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (7954843239286609920, 8178510000000000000, 58): figura con max voti: FALSE ASSERTION (4 voti)
#
#
# Record (492369763312032128, 17520700000000000000, 59): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 2, 'FALSE ASSERTION': 0, 'HYPERBOLE': 3, 'OTHER': 0, 'OXYMORON': 2, 'RHETORICAL QUESTION': 0}
# Record (492369763312032128, 17520700000000000000, 59): figura con max voti: HYPERBOLE (3 voti)
#
#
# Record (9470135544203663360, 7580360000000000000, 60): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 2, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 3, 'RHETORICAL QUESTION': 0}
# Record (9470135544203663360, 7580360000000000000, 60): figura con max voti: OXYMORON (3 voti)
#
#
# Record (11899879421757480960, 699644000000000000, 61): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 1, 'OTHER': 2, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (11899879421757480960, 699644000000000000, 61): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (8482609725250125824, 11859000000000000000, 62): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 4, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (8482609725250125824, 11859000000000000000, 62): figura con max voti: EUPHEMISM (4 voti)
#
#
# Record (2968926351009075200, 10391400000000000000, 63): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (2968926351009075200, 10391400000000000000, 63): figura con max voti: OTHER (3 voti)
#
#
# Record (7477401530957351936, 1206180000000000000, 64): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 0, 'OXYMORON': 3, 'RHETORICAL QUESTION': 6}
# Record (7477401530957351936, 1206180000000000000, 64): figura con max voti: RHETORICAL QUESTION (6 voti)
#
#
# Record (16971453668517500928, 15948200000000000000, 65): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (16971453668517500928, 15948200000000000000, 65): figura con max voti: FALSE ASSERTION (2 voti)
#
#
# Record (13943343828615460864, 9688060000000000000, 66): voti per figura: {'ANALOGY': 4, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (13943343828615460864, 9688060000000000000, 66): figura con max voti: ANALOGY (4 voti)
#
#
# Record (888612363643747712, 9901380000000000000, 67): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (888612363643747712, 9901380000000000000, 67): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (16300389213436499968, 7681940000000000000, 68): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 5, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (16300389213436499968, 7681940000000000000, 68): figura con max voti: OTHER (5 voti)
#
#
# Record (11854247542220259328, 17907300000000000000, 69): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (11854247542220259328, 17907300000000000000, 69): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (13001943395368790016, 10475000000000000000, 70): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 1, 'FALSE ASSERTION': 4, 'HYPERBOLE': 2, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (13001943395368790016, 10475000000000000000, 70): figura con max voti: FALSE ASSERTION (4 voti)
#
#
# Record (14468596749483630592, 4827130000000000000, 71): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (14468596749483630592, 4827130000000000000, 71): figura con max voti: RHETORICAL QUESTION (3 voti)
#
#
# Record (255308143867597184, 3714510000000000000, 72): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 2, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 1}
# Record (255308143867597184, 3714510000000000000, 72): figura con max voti: ANALOGY (2 voti)
#
#
# Record (8182077132297058304, 4587260000000000000, 73): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 4, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (8182077132297058304, 4587260000000000000, 73): figura con max voti: OTHER (4 voti)
#
#
# Record (14222935602055790592, 11326200000000000000, 74): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 1, 'OTHER': 0, 'OXYMORON': 3, 'RHETORICAL QUESTION': 4}
# Record (14222935602055790592, 11326200000000000000, 74): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (6358833546371151872, 2866560000000000000, 75): voti per figura: {'ANALOGY': 3, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (6358833546371151872, 2866560000000000000, 75): figura con max voti: ANALOGY (3 voti)
#
#
# Record (4712286480051747840, 4224410000000000000, 76): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (4712286480051747840, 4224410000000000000, 76): figura con max voti: OTHER (3 voti)
#
#
# Record (7489313936521549824, 7078800000000000000, 77): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 4, 'EUPHEMISM': 1, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (7489313936521549824, 7078800000000000000, 77): figura con max voti: CONTEXT SHIFT (4 voti)
#
#
# Record (10282731906424629248, 15817800000000000000, 78): voti per figura: {'ANALOGY': 5, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 4}
# Record (10282731906424629248, 15817800000000000000, 78): figura con max voti: ANALOGY (5 voti)
#
#
# Record (5969871576465133568, 14017200000000000000, 79): voti per figura: {'ANALOGY': 3, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 2, 'RHETORICAL QUESTION': 0}
# Record (5969871576465133568, 14017200000000000000, 79): figura con max voti: ANALOGY (3 voti)
#
#
# Record (4360074657789536256, 16013400000000000000, 80): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 3, 'FALSE ASSERTION': 1, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (4360074657789536256, 16013400000000000000, 80): figura con max voti: EUPHEMISM (3 voti)
#
#
# Record (5724857037789025280, 13083000000000000000, 81): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 4, 'OTHER': 0, 'OXYMORON': 2, 'RHETORICAL QUESTION': 4}
# Record (5724857037789025280, 13083000000000000000, 81): figura con max voti: HYPERBOLE (4 voti)
#
#
# Record (13415829529808369664, 7787860000000000000, 82): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 2, 'FALSE ASSERTION': 1, 'HYPERBOLE': 2, 'OTHER': 0, 'OXYMORON': 1, 'RHETORICAL QUESTION': 4}
# Record (13415829529808369664, 7787860000000000000, 82): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (15452154017271209984, 11998800000000000000, 83): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (15452154017271209984, 11998800000000000000, 83): figura con max voti: OTHER (2 voti)
#
#
# Record (15145496112429019136, 11505300000000000000, 84): voti per figura: {'ANALOGY': 5, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 1, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (15145496112429019136, 11505300000000000000, 84): figura con max voti: ANALOGY (5 voti)
#
#
# Record (15169059911459409920, 10309200000000000000, 85): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 2, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (15169059911459409920, 10309200000000000000, 85): figura con max voti: EUPHEMISM (2 voti)
#
#
# Record (3037383543302795776, 6283640000000000000, 86): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 3, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (3037383543302795776, 6283640000000000000, 86): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (11755500963030939648, 12431600000000000000, 87): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 5, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (11755500963030939648, 12431600000000000000, 87): figura con max voti: OTHER (5 voti)
#
#
# Record (9408805770120683520, 2035190000000000000, 88): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 6, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (9408805770120683520, 2035190000000000000, 88): figura con max voti: HYPERBOLE (6 voti)
#
#
# Record (1679217763483685120, 6187690000000000000, 89): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (1679217763483685120, 6187690000000000000, 89): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (2432806416627402752, 11492500000000000000, 90): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 2, 'RHETORICAL QUESTION': 0}
# Record (2432806416627402752, 11492500000000000000, 90): figura con max voti: OTHER (2 voti)
#
#
# Record (16626886395331850240, 7533790000000000000, 91): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 3, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (16626886395331850240, 7533790000000000000, 91): figura con max voti: EUPHEMISM (3 voti)
#
#
# Record (4520804865264936960, 12052700000000000000, 92): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 5, 'HYPERBOLE': 2, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (4520804865264936960, 12052700000000000000, 92): figura con max voti: FALSE ASSERTION (5 voti)
#
#
# Record (12561098575626790912, 12674400000000000000, 93): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 4, 'FALSE ASSERTION': 2, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (12561098575626790912, 12674400000000000000, 93): figura con max voti: EUPHEMISM (4 voti)
#
#
# Record (12802596261741490176, 6395060000000000000, 94): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 1, 'FALSE ASSERTION': 4, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (12802596261741490176, 6395060000000000000, 94): figura con max voti: FALSE ASSERTION (4 voti)
#
#
# Record (11534803039351519232, 14401400000000000000, 95): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 5, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (11534803039351519232, 14401400000000000000, 95): figura con max voti: OTHER (5 voti)
#
#
# Record (1236265448438971904, 4088920000000000000, 96): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 3, 'OTHER': 1, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (1236265448438971904, 4088920000000000000, 96): figura con max voti: HYPERBOLE (3 voti)
#
#
# Record (9838181499890583552, 10423300000000000000, 97): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 2, 'HYPERBOLE': 2, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (9838181499890583552, 10423300000000000000, 97): figura con max voti: FALSE ASSERTION (2 voti)
#
#
# Record (3078947007140050944, 10710000000000000000, 98): voti per figura: {'ANALOGY': 3, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 3, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (3078947007140050944, 10710000000000000000, 98): figura con max voti: ANALOGY (3 voti)
#
#
# Record (17101699480099239936, 15609300000000000000, 99): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 2, 'FALSE ASSERTION': 5, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (17101699480099239936, 15609300000000000000, 99): figura con max voti: FALSE ASSERTION (5 voti)
#
#
# Record (10426144657201930240, 4379940000000000000, 100): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 2, 'OTHER': 4, 'OXYMORON': 1, 'RHETORICAL QUESTION': 0}
# Record (10426144657201930240, 4379940000000000000, 100): figura con max voti: OTHER (4 voti)
#
#
# Record (14571755448335099904, 8064450000000000000, 101): voti per figura: {'ANALOGY': 4, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 1, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (14571755448335099904, 8064450000000000000, 101): figura con max voti: ANALOGY (4 voti)
#
#
# Record (12148897515124049920, 10230900000000000000, 102): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 4}
# Record (12148897515124049920, 10230900000000000000, 102): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (364716304175925376, 7002360000000000000, 103): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 2, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (364716304175925376, 7002360000000000000, 103): figura con max voti: CONTEXT SHIFT (2 voti)
#
#
# Record (12099038560420169728, 16675900000000000000, 104): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 4, 'EUPHEMISM': 1, 'FALSE ASSERTION': 1, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (12099038560420169728, 16675900000000000000, 104): figura con max voti: CONTEXT SHIFT (4 voti)
#
#
# Record (15909640808401659904, 4919990000000000000, 105): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 2, 'FALSE ASSERTION': 3, 'HYPERBOLE': 1, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (15909640808401659904, 4919990000000000000, 105): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (702317291372904320, 2344620000000000000, 106): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 1, 'FALSE ASSERTION': 5, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 1}
# Record (702317291372904320, 2344620000000000000, 106): figura con max voti: FALSE ASSERTION (5 voti)
#
#
# Record (3045493691802176000, 2186550000000000000, 107): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 5, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (3045493691802176000, 2186550000000000000, 107): figura con max voti: CONTEXT SHIFT (5 voti)
#
#
# Record (12840277770070130688, 17885300000000000000, 108): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 1, 'RHETORICAL QUESTION': 3}
# Record (12840277770070130688, 17885300000000000000, 108): figura con max voti: RHETORICAL QUESTION (3 voti)
#
#
# Record (1679217763483685120, 8067560000000000000, 109): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (1679217763483685120, 8067560000000000000, 109): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (7987151303712674816, 7829230000000000000, 110): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 1, 'FALSE ASSERTION': 3, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (7987151303712674816, 7829230000000000000, 110): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (8553934668525359104, 6122080000000000000, 111): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 2, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (8553934668525359104, 6122080000000000000, 111): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (527554389017052224, 13774800000000000000, 112): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 4, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 2}
# Record (527554389017052224, 13774800000000000000, 112): figura con max voti: CONTEXT SHIFT (4 voti)
#
#
# Record (15986361946082170880, 16848500000000000000, 113): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 3, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 5}
# Record (15986361946082170880, 16848500000000000000, 113): figura con max voti: RHETORICAL QUESTION (5 voti)
#
#
# Record (16653175777918050304, 11658100000000000000, 114): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 1, 'OTHER': 0, 'OXYMORON': 3, 'RHETORICAL QUESTION': 3}
# Record (16653175777918050304, 11658100000000000000, 114): figura con max voti: FALSE ASSERTION (3 voti)
#
#
# Record (14672930942777870336, 4389960000000000000, 115): voti per figura: {'ANALOGY': 1, 'CONTEXT SHIFT': 1, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 4, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (14672930942777870336, 4389960000000000000, 115): figura con max voti: OTHER (4 voti)
#
#
# Record (7501166755663576064, 17666000000000000000, 116): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 3, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (7501166755663576064, 17666000000000000000, 116): figura con max voti: OTHER (3 voti)
#
#
# Record (18298855339031560192, 12680200000000000000, 117): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 2, 'HYPERBOLE': 0, 'OTHER': 0, 'OXYMORON': 2, 'RHETORICAL QUESTION': 3}
# Record (18298855339031560192, 12680200000000000000, 117): figura con max voti: RHETORICAL QUESTION (3 voti)
#
#
# Record (16565537520034279424, 12210400000000000000, 118): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 2, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 2, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (16565537520034279424, 12210400000000000000, 118): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# Record (14849029575208689664, 6295240000000000000, 119): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 0, 'EUPHEMISM': 0, 'FALSE ASSERTION': 3, 'HYPERBOLE': 4, 'OTHER': 0, 'OXYMORON': 0, 'RHETORICAL QUESTION': 0}
# Record (14849029575208689664, 6295240000000000000, 119): figura con max voti: HYPERBOLE (4 voti)
#
#
# Record (17406266981620549632, 13932800000000000000, 120): voti per figura: {'ANALOGY': 0, 'CONTEXT SHIFT': 2, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 0, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 4}
# Record (17406266981620549632, 13932800000000000000, 120): figura con max voti: RHETORICAL QUESTION (4 voti)
#
#
# Record (10279940017783449600, 2387680000000000000, 121): voti per figura: {'ANALOGY': 2, 'CONTEXT SHIFT': 3, 'EUPHEMISM': 0, 'FALSE ASSERTION': 0, 'HYPERBOLE': 2, 'OTHER': 1, 'OXYMORON': 0, 'RHETORICAL QUESTION': 3}
# Record (10279940017783449600, 2387680000000000000, 121): figura con max voti: CONTEXT SHIFT (3 voti)
#
#
# 122

# %%
# Rinominare la colonna 'most_frequent_label' in 'actual'
df_actual = df_most_frequent.rename(columns={'most_frequent_label': 'actual'})

# Selezionare solo le colonne desiderate
df_actual = df_actual[['index', 'post_id', 'reply_id', 'actual']]

# Salvare su file CSV
df_actual.to_csv('actuals/global_actual_labels.csv', index=False)

print("File 'actual_labels.csv' creato con successo.")
# Out:
# File 'actual_labels.csv' creato con successo.

# %% [markdown]
# ## Genere: Estrazione etichetta più frequente per ogni record

# %%
import pandas as pd

# Lista annotatori e gruppo per genere (modifica se necessario)
male_annotators = ["Alessandro", "Michael", "Michele"]
female_annotators = ["Cristina", "Elisa", "Eliana"]

# Prepara i dataframe indicizzati per ogni annotatore
dfs_figs = {}
for name in sheet_names:
    df_tmp = final_cleaned[name][['post_id', 'reply_id', 'index'] + all_figures].copy()
    dfs_figs[name] = df_tmp.set_index(['post_id', 'reply_id', 'index'])

# Trova record comuni a tutti
common_index = set(dfs_figs[male_annotators[0]].index)
for name in sheet_names[1:]:
    common_index = common_index.intersection(dfs_figs[name].index)
common_index = list(common_index)

results = []

for idx in common_index:
    # Per gruppo maschile: prendi righe solo di annotatori maschi
    male_matrix = pd.DataFrame([dfs_figs[name].loc[idx].values for name in male_annotators], columns=all_figures)
    male_votes = male_matrix.sum(axis=0)
    male_max_votes = male_votes.max()
    male_top_figures = male_votes[male_votes == male_max_votes].index.tolist()
    male_top_label = sorted(male_top_figures)[0] if male_top_figures else None

    # Per gruppo femminile: prendi righe solo di annotatori femmine
    female_matrix = pd.DataFrame([dfs_figs[name].loc[idx].values for name in female_annotators], columns=all_figures)
    female_votes = female_matrix.sum(axis=0)
    female_max_votes = female_votes.max()
    female_top_figures = female_votes[female_votes == female_max_votes].index.tolist()
    female_top_label = sorted(female_top_figures)[0] if female_top_figures else None

    results.append({
        'index': idx[2],
        'post_id': idx[0],
        'reply_id': idx[1],
        'male_most_frequent_label': male_top_label,
        'male_votes': male_max_votes,
        'female_most_frequent_label': female_top_label,
        'female_votes': female_max_votes
    })

df_by_gender = pd.DataFrame(results)
print(f"Totale record analizzati: {len(df_by_gender)}")
df_by_gender.head()
# Out:
# Totale record analizzati: 122
#    index               post_id              reply_id male_most_frequent_label  \
# 0     41   7892378751459500032  16252800000000000000      RHETORICAL QUESTION
# 1      2   7155693771356047360  18161900000000000000                    OTHER
# 2    101  14571755448335099904   8064450000000000000                  ANALOGY
# 3     36   9117711307358630912   7916660000000000000                  ANALOGY
# 4      3   5929177359346716672   5855670000000000000          FALSE ASSERTION
#
#    male_votes female_most_frequent_label  female_votes
# 0           2        RHETORICAL QUESTION             2
# 1           3                      OTHER             2
# 2           2                    ANALOGY             2
# 3           1              CONTEXT SHIFT             1
# 4           2                  EUPHEMISM             2

# %%
# Salva solo dati maschili in un file
df_male = df_by_gender[['index', 'post_id', 'reply_id', 'male_most_frequent_label', 'male_votes']]
df_male = df_male.rename(columns={'male_most_frequent_label': 'actual'})

df_male.to_csv('actuals/male_actual_labels.csv', index=False)

# Salva solo dati femminili in un file
df_female = df_by_gender[['index', 'post_id', 'reply_id', 'female_most_frequent_label', 'female_votes']]
df_female = df_female.rename(columns={'female_most_frequent_label': 'actual'})

df_female.to_csv('actuals/female_actual_labels.csv', index=False)

# %% [markdown]
# ## Generazione: Estrazione etichetta più frequente per ogni record

# %%
import pandas as pd

# Lista annotatori e gruppo per genere (modifica se necessario)
genx_annotators = ["Alessandro", "Cristina"]
geny_annotators = ["Michele", "Eliana"]
genz_annotators = ["Michael", "Elisa"]

# Prepara i dataframe indicizzati per ogni annotatore
dfs_figs = {}
for name in sheet_names:
    df_tmp = final_cleaned[name][['post_id', 'reply_id', 'index'] + all_figures].copy()
    dfs_figs[name] = df_tmp.set_index(['post_id', 'reply_id', 'index'])

# Trova record comuni a tutti
common_index = set(dfs_figs[sheet_names[0]].index)
for name in sheet_names[1:]:
    common_index = common_index.intersection(dfs_figs[name].index)
common_index = list(common_index)

results = []

for idx in common_index:
    # Gruppo Gen X
    genx_matrix = pd.DataFrame([dfs_figs[name].loc[idx].values for name in genx_annotators], columns=all_figures)
    genx_votes = genx_matrix.sum(axis=0)
    genx_max_votes = genx_votes.max()
    genx_top_figures = genx_votes[genx_votes == genx_max_votes].index.tolist()
    genx_top_label = sorted(genx_top_figures)[0] if genx_top_figures else None

    # Gruppo Gen Y
    geny_matrix = pd.DataFrame([dfs_figs[name].loc[idx].values for name in geny_annotators], columns=all_figures)
    geny_votes = geny_matrix.sum(axis=0)
    geny_max_votes = geny_votes.max()
    geny_top_figures = geny_votes[geny_votes == geny_max_votes].index.tolist()
    geny_top_label = sorted(geny_top_figures)[0] if geny_top_figures else None

    # Gruppo Gen Z
    genz_matrix = pd.DataFrame([dfs_figs[name].loc[idx].values for name in genz_annotators], columns=all_figures)
    genz_votes = genz_matrix.sum(axis=0)
    genz_max_votes = genz_votes.max()
    genz_top_figures = genz_votes[genz_votes == genz_max_votes].index.tolist()
    genz_top_label = sorted(genz_top_figures)[0] if genz_top_figures else None

    results.append({
        'index': idx[2],
        'post_id': idx[0],
        'reply_id': idx[1],
        'genx_most_frequent_label': genx_top_label,
        'genx_votes': genx_max_votes,
        'geny_most_frequent_label': geny_top_label,
        'geny_votes': geny_max_votes,
        'genz_most_frequent_label': genz_top_label,
        'genz_votes': genz_max_votes,
    })

df_by_generation = pd.DataFrame(results)
print(f"Totale record analizzati: {len(df_by_generation)}")
df_by_generation.head()
# Out:
# Totale record analizzati: 122
#    index               post_id              reply_id genx_most_frequent_label  \
# 0     41   7892378751459500032  16252800000000000000      RHETORICAL QUESTION
# 1      2   7155693771356047360  18161900000000000000                    OTHER
# 2    101  14571755448335099904   8064450000000000000                  ANALOGY
# 3     36   9117711307358630912   7916660000000000000            CONTEXT SHIFT
# 4      3   5929177359346716672   5855670000000000000                EUPHEMISM
#
#    genx_votes geny_most_frequent_label  geny_votes genz_most_frequent_label  \
# 0           2            CONTEXT SHIFT           1                HYPERBOLE
# 1           2                    OTHER           2            CONTEXT SHIFT
# 2           1                  ANALOGY           1                  ANALOGY
# 3           2                    OTHER           1                  ANALOGY
# 4           1                EUPHEMISM           1                EUPHEMISM
#
#    genz_votes
# 0           1
# 1           1
# 2           2
# 3           1
# 4           1

# %%
# Estrai dati per ogni generazione
df_genx = df_by_generation[['index', 'post_id', 'reply_id', 'genx_most_frequent_label', 'genx_votes']]
df_genx = df_genx.rename(columns={'genx_most_frequent_label': 'actual'})

df_geny = df_by_generation[['index', 'post_id', 'reply_id', 'geny_most_frequent_label', 'geny_votes']]
df_geny = df_geny.rename(columns={'geny_most_frequent_label': 'actual'})

df_genz = df_by_generation[['index', 'post_id', 'reply_id', 'genz_most_frequent_label', 'genz_votes']]
df_genz = df_genz.rename(columns={'genz_most_frequent_label': 'actual'})

# Salva su file CSV separati
df_genx.to_csv('actuals/genx_actual_labels.csv', index=False)
df_geny.to_csv('actuals/geny_actual_labels.csv', index=False)
df_genz.to_csv('actuals/genz_actual_labels.csv', index=False)
